# %% [markdown]
# ### 1. Análise exploratória de dados (felipe)

# %% [markdown]
# ### 2. Featuring Engineering (Felipe)

# %% [markdown]
# ### 3. Aprendizagem Supervisionada (Gustavo)

# %% [markdown]
# ### 4.1 Aprendizagem não supervisionada:
# ### Clusterização e redução de dimensionalidade (Karol)

# %% [markdown]
# ### 4.2 Análise de Associação e Outlier (Ana)

# %% [markdown]
# ### 5. Métricas de avaliação e comparação
